# %%
import pandas as pd
import matplotlib.pyplot as plt
wsb_df = pd.read_excel("C:/Users/Shanmukha Reddy/Desktop/FDS/Accidents Classified according to Non-Use of Safety Device ( Non-Wearing of Seat Belt) by Victims during the calendar year 2017-2022.xlsx")
wsb_df.head(222)
# Out:
#      S.No      States/Uts  Drivers_PersonsKilled_Number  \
# 0       1  Andhra Pradesh                           441
# 1       2  Andhra Pradesh                           395
# 2       3  Andhra Pradesh                           335
# 3       4  Andhra Pradesh                           230
# 4       5  Andhra Pradesh                           241
# ..    ...             ...                           ...
# 217   218      Puducherry                             2
# 218   219      Puducherry                             0
# 219   220      Puducherry                             0
# 220   221      Puducherry                             0
# 221   222      Puducherry                             0
#
#      Drivers_PersonsKilled_Rank  Drivers_PersonsInjured_GrevioslyInjured  \
# 0                             5                                      916
# 1                             9                                      433
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = "C:/Users/Shanmukha Reddy/Desktop/FDS/Accidents Classified according to Non-Use of Safety Device ( Non-Wearing of Seat Belt) by Victims during the calendar year 2017-2022.xlsx"
wsb_df = pd.read_excel(file_path)

# Plotting two specific columns
plt.figure(figsize=(15, 5))

# Plot the selected columns
plt.plot(wsb_df['Year'], wsb_df['Drivers_PersonsKilled_Number'], label='Drivers Killed')
plt.plot(wsb_df['Year'], wsb_df['Passengers_PersonsKilled_Number'], label='Passengers Killed')

# Adding labels and title
plt.xlabel("Year")
plt.ylabel("Number of Persons Killed")
plt.title("Drivers vs. Passengers Killed Over Years")
plt.legend()

# Display the plot
plt.show()

# %%
wsb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   S.No                                         222 non-null    int64
#  1   States/Uts                                   222 non-null    object
#  2   Drivers_PersonsKilled_Number                 222 non-null    int64
#  3   Drivers_PersonsKilled_Rank                   222 non-null    int64
#  4   Drivers_PersonsInjured_GrevioslyInjured      222 non-null    int64
#  5   Drivers_PersonsInjured_MinorInjured          222 non-null    int64
#  6   Drivers_Total Injured                        222 non-null    int64
#  7   Passengers_PersonsKilled_Number              222 non-null    int64
#  8   Passengers_PersonsKilled_Rank                222 non-null    int64
#  9   Passengers_PersonsInjured_GreviouslyInjured  222 non-null    int64
# ...

# %%
import pandas as pd

# Load the Excel file into a DataFrame
file_path = "C:/Users/Shanmukha Reddy/Desktop/FDS/Accidents Classified according to Non-Use of Safety Device ( Non-Wearing of Seat Belt) by Victims during the calendar year 2017-2022.xlsx"
wsb_df = pd.read_excel(file_path)

# Display the first few rows and the columns to identify the correct column name
print("Column Names:", wsb_df.columns)
print(wsb_df.head())

# Now, assuming 'Rank' should be one of the columns such as 'Drivers_PersonsKilled_Rank' or 'Passengers_PersonsKilled_Rank'
# Let's use 'Drivers_PersonsKilled_Rank' as an example
wsb_df['mavg_12'] = wsb_df['Drivers_PersonsKilled_Rank'].rolling(window=12).mean().shift(1)

# Set the display format for floating-point numbers
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Display the data from the 36th row onwards
wsb_df_subset = wsb_df[['Drivers_PersonsKilled_Rank', 'mavg_12']][36:]
print(wsb_df_subset)
# Out:
# Column Names: Index(['S.No', 'States/Uts', 'Drivers_PersonsKilled_Number',
#        'Drivers_PersonsKilled_Rank', 'Drivers_PersonsInjured_GrevioslyInjured',
#        'Drivers_PersonsInjured_MinorInjured', 'Drivers_Total Injured',
#        'Passengers_PersonsKilled_Number', 'Passengers_PersonsKilled_Rank',
#        'Passengers_PersonsInjured_GreviouslyInjured',
#        'Passengers_PersonsInjured_MinorInjured',
#        'Passengers_PersonsInjured_Total Injured', 'Year'],
#       dtype='object')
#    S.No      States/Uts  Drivers_PersonsKilled_Number  \
# 0     1  Andhra Pradesh                           441
# 1     2  Andhra Pradesh                           395
# 2     3  Andhra Pradesh                           335
# 3     4  Andhra Pradesh                           230
# 4     5  Andhra Pradesh                           241
#
#    Drivers_PersonsKilled_Rank  Drivers_PersonsInjured_GrevioslyInjured  \
# 0                           5                                      916
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file
file_path ="C:/Users/Shanmukha Reddy/Desktop/FDS/Accidents Classified according to Non-Use of Safety Device ( Non-Wearing of Seat Belt) by Victims during the calendar year 2017-2022.xlsx"
wsb_df = pd.read_excel(file_path)

# Plotting 'Drivers_PersonsKilled_Number' and 'Drivers_PersonsKilled_Rank' starting from the 13th row (index 12 onward)
plt.figure(figsize=(10, 4))
plt.xlabel('Year')
plt.ylabel('Value')

# Adding labels to the plots
plt.plot(wsb_df['Year'][12:], wsb_df['Drivers_PersonsKilled_Number'][12:], label='Drivers Persons Killed Number')
plt.plot(wsb_df['Year'][12:], wsb_df['Drivers_PersonsKilled_Rank'][12:], '.', label='Drivers Persons Killed Rank')

# Displaying the legend with the correct labels
plt.legend()
plt.title('Drivers Persons Killed Data (Starting from 13th Record)')
plt.show()

# %%
import numpy as np

def get_mape(actual, predicted):
    y_true, y_pred = np.array(actual), np.array(predicted)
    return np.round(np.mean(np.abs((y_true - y_pred) / y_true)) * 100, 2)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

# Load the Excel file
file_path = "C:/Users/Shanmukha Reddy/Desktop/FDS/Accidents Classified according to Non-Use of Safety Device ( Non-Wearing of Seat Belt) by Victims during the calendar year 2017-2022.xlsx"
wsb_df = pd.read_excel(file_path)

# Calculate a 12-month moving average for 'Drivers_PersonsKilled_Rank'
wsb_df['mavg_12'] = wsb_df['Drivers_PersonsKilled_Rank'].rolling(window=12).mean()

# Drop NaN values that result from the rolling calculation
wsb_df.dropna(subset=['mavg_12'], inplace=True)

# Calculate RMSE between 'Drivers_PersonsKilled_Rank' and its 12-month moving average from index 36 onward
rmse = np.sqrt(mean_squared_error(wsb_df['Drivers_PersonsKilled_Rank'][36:].values, wsb_df['mavg_12'][36:].values))
print("RMSE:", rmse)

# Compare the RMSE to a specific np.float64 value
comparison_value = np.float64(0.6357842046317105)
print("RMSE is equal to comparison value:", rmse == comparison_value)
# Out:
# RMSE: 9.224122963428254
# RMSE is equal to comparison value: False

# %%
# Calculate Exponential Weighted Moving Average (EWMA) for 'Drivers_PersonsKilled_Rank'
wsb_df['ewm'] = wsb_df['Drivers_PersonsKilled_Rank'].ewm(alpha=0.2).mean()

# Display the DataFrame to see the new 'ewm' column
wsb_df[['Drivers_PersonsKilled_Rank', 'ewm']].head()
# Out:
#     Drivers_PersonsKilled_Rank   ewm
# 11                          24 24.00
# 12                          11 16.78
# 13                          18 17.28
# 14                          16 16.85
# 15                          17 16.89

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
wsb_df[36:]
# Out:
#      S.No        States/Uts  Drivers_PersonsKilled_Number  \
# 47     48           Haryana                           213
# 48     49  Himachal Pradesh                            23
# 49     50  Himachal Pradesh                           262
# 50     51  Himachal Pradesh                           273
# 51     52  Himachal Pradesh                           326
# ..    ...               ...                           ...
# 217   218        Puducherry                             2
# 218   219        Puducherry                             0
# 219   220        Puducherry                             0
# 220   221        Puducherry                             0
# 221   222        Puducherry                             0
#
#      Drivers_PersonsKilled_Rank  Drivers_PersonsInjured_GrevioslyInjured  \
# 47                           14                                      177
# 48                           23                                       26
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the get_mape function to calculate Mean Absolute Percentage Error (MAPE)
def get_mape(actual, forecast):
    actual, forecast = np.array(actual), np.array(forecast)
    # Avoid division by zero by filtering out zero values
    mask = actual != 0
    actual, forecast = actual[mask], forecast[mask]
    return np.mean(np.abs((actual - forecast) / actual)) * 100

# Calculate MAPE between 'Drivers_PersonsKilled_Rank' and its Exponential Weighted Moving Average ('ewm')
mape_value = get_mape(wsb_df[['Drivers_PersonsKilled_Rank']][36:].values, wsb_df[['ewm']][36:].values)
print("MAPE:", mape_value)

# Compare the MAPE to the given value
comparison_value = np.float64(43266946650.46)
print("MAPE is approximately equal to comparison value:", np.isclose(mape_value, comparison_value))

# Plotting the actual vs. forecasted values using exponential moving average
plt.figure(figsize=(10, 4))
plt.xlabel('Months')
plt.ylabel('Quantity')
plt.plot(wsb_df['Drivers_PersonsKilled_Rank'][36:], label='Actual Drivers Persons Killed Rank')
plt.plot(wsb_df['ewm'][36:], '.', label='Exponential Moving Average (ewm)')
plt.legend()
plt.title('Actual vs Forecasted Drivers Persons Killed Rank using Exponential Moving Average')
plt.show()
# Out:
# MAPE: 78.18812006828702
# MAPE is approximately equal to comparison value: False

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import numpy as np
import matplotlib.pyplot as plt

# Ensure the column 'Drivers_PersonsKilled_Rank' is used instead of 'Rank'
rank_series = wsb_df['Drivers_PersonsKilled_Rank'].dropna()  # Drop NaN values to avoid errors in decomposition

# Decomposing the time series with the additive model
ts_decompose = seasonal_decompose(rank_series, model='additive', period=12)

# Extracting the seasonal and trend components
wsb_df['seasonal'] = ts_decompose.seasonal
wsb_df['trend'] = ts_decompose.trend

# Plotting the decomposed time series components
ts_plot = ts_decompose.plot()
ts_plot.suptitle('Decomposition of Drivers Persons Killed Rank Time Series', fontsize=5)
plt.show()
